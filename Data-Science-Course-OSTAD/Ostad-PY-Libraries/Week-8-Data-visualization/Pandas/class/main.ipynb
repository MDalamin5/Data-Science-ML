# %%
import pandas as pd
import numpy as np

# %%
dates = pd.date_range('1/1/2022', periods=500)
dates
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2023-05-06', '2023-05-07', '2023-05-08', '2023-05-09',
#                '2023-05-10', '2023-05-11', '2023-05-12', '2023-05-13',
#                '2023-05-14', '2023-05-15'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
data1 = np.random.randn(500, 3)
data1
# Out:
# array([[ 1.36323531, -0.37882263, -0.70932636],
#        [ 0.74729577, -1.17699049, -1.20021499],
#        [ 0.05860494,  0.71389239,  1.52837744],
#        ...,
#        [-0.83162325,  1.08840125, -0.07101831],
#        [-0.0251657 ,  1.6845385 , -0.91785268],
#        [ 0.08939184, -1.48020181, -0.26716384]])

# %%
df1 = pd.DataFrame(data = data1, index= dates, columns=['A', 'B', 'C'])
df1
# Out:
#                    A         B         C
# 2022-01-01  1.363235 -0.378823 -0.709326
# 2022-01-02  0.747296 -1.176990 -1.200215
# 2022-01-03  0.058605  0.713892  1.528377
# 2022-01-04 -0.054404  0.425197  1.656849
# 2022-01-05 -1.660276  1.789421 -1.382799
# ...              ...       ...       ...
# 2023-05-11 -0.676339  0.688610  0.888108
# 2023-05-12 -0.523677 -0.123588  0.956404
# 2023-05-13 -0.831623  1.088401 -0.071018
# 2023-05-14 -0.025166  1.684539 -0.917853
# 2023-05-15  0.089392 -1.480202 -0.267164
#
# [500 rows x 3 columns]

# %%
data2 = np.random.rand(20, 3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data= data2, columns= col)
df2
# Out:
#            X         Y         Z
# 0   0.689936  0.254016  0.804497
# 1   0.631314  0.004439  0.507485
# 2   0.228431  0.223515  0.537311
# 3   0.354046  0.488642  0.767950
# 4   0.092394  0.866330  0.564040
# 5   0.492677  0.420818  0.540161
# 6   0.839774  0.733907  0.398020
# 7   0.885257  0.823016  0.373575
# 8   0.167354  0.873622  0.771884
# 9   0.716911  0.377161  0.064547
# 10  0.760640  0.691899  0.071510
# 11  0.584817  0.588413  0.585743
# 12  0.190649  0.723693  0.545938
# 13  0.693556  0.204238  0.955575
# 14  0.664901  0.542774  0.987791
# 15  0.239131  0.673337  0.958198
# 16  0.712540  0.261480  0.236717
# 17  0.206721  0.914842  0.748520
# 18  0.986815  0.789493  0.930623
# 19  0.953189  0.522151  0.874194

# %%
df1['A'].hist(edgecolor = 'black')
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=30, edgecolor='black', figsize=(12, 5))
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=3)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins = 40, figsize=(12, 12), edgecolor='yellow')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind='hist', bins=30, figsize=(12, 10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use('bmh')

# %%
df1['B'].plot(kind='hist', bins=30, figsize=(10, 10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.style.use('dark_background')
df1['C'].plot(kind='hist', bins=30, figsize=(10, 10), edgecolor='blue')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['X'].plot(kind='hist', bins = 30, edgecolor='blue')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2
# Out:
#            X         Y         Z
# 0   0.689936  0.254016  0.804497
# 1   0.631314  0.004439  0.507485
# 2   0.228431  0.223515  0.537311
# 3   0.354046  0.488642  0.767950
# 4   0.092394  0.866330  0.564040
# 5   0.492677  0.420818  0.540161
# 6   0.839774  0.733907  0.398020
# 7   0.885257  0.823016  0.373575
# 8   0.167354  0.873622  0.771884
# 9   0.716911  0.377161  0.064547
# 10  0.760640  0.691899  0.071510
# 11  0.584817  0.588413  0.585743
# 12  0.190649  0.723693  0.545938
# 13  0.693556  0.204238  0.955575
# 14  0.664901  0.542774  0.987791
# 15  0.239131  0.673337  0.958198
# 16  0.712540  0.261480  0.236717
# 17  0.206721  0.914842  0.748520
# 18  0.986815  0.789493  0.930623
# 19  0.953189  0.522151  0.874194

# %%
df2['X'].plot(kind='line')
# Out:
# <Axes: >

# %%
df2.plot(kind='line')
# Out:
# <Axes: >

# %%
df2['X'].plot(kind='area',)
# Out:
# <Axes: >

# %%
df2.plot(kind='area')
# Out:
# <Axes: >

# %%
df2['X'].plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
df2.plot(kind='bar', figsize=(15, 5))
# Out:
# <Axes: >

# %%
df2.plot(kind='barh', figsize=(10,10))
# Out:
# <Axes: >

# %%
df2.plot(kind='bar', stacked=True, figsize=(10, 5))
# Out:
# <Axes: >

# %% [markdown]
# # HISTOGRAM

# %%
df1.plot(kind='scatter', x='A', y='B', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', figsize=(12, 3),)
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.line(x='A', y='B', figsize=(12, 3),)
# Out:
# <Axes: xlabel='A'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 4))
# Out:
# <Axes: xlabel='X'>

# %%
df1.plot.scatter(x='A', y='B', c='0.7', figsize=(13, 5))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c='C', s=90, cmap='coolwarm', figsize=(15, 5))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*100, figsize=(15, 4))
# Out:
# /Users/mdalamin/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A', y='B', figsize=(15, 5), gridsize=30, cmap='Oranges')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
gas = pd.read_csv('gas_prices.csv')
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas['UK'].plot()
# Out:
# <Axes: >

# %%
gas.plot(x='Year', y='USA')
# Out:
# <Axes: xlabel='Year'>

# %%
gas.plot(x='Year', y='USA', xticks=gas.Year[::3].tolist(), figsize=(15, 5))
# Out:
# <Axes: xlabel='Year'>

# %%
plt.subplots(figsize=(15, 5))
plt.plot(gas['Year'], gas['USA'])
plt.plot(gas['Year'], gas['UK'])
plt.plot(gas['Year'], gas['Canada'])
plt.xticks(gas.Year[::3].tolist())
plt.show()

# %%
plt.subplots(figsize=(15, 5))
plt.title('Gas Price Over the time(in USD)', fontdict={'fontweight' : 'bold', 'fontsize' : 18, 'color' : 'g'})
# plt.plot(gas['Year'], gas['USA'])
plt.plot(gas.Year, gas.USA, 'b.-', label='USA')
plt.plot(gas.Year, gas['Canada'], 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='South Korea')
plt.plot(gas.Year, gas['Australia'], 'y.-', label='Aus')
plt.xlabel('Dller')
plt.ylabel('Year')
plt.legend()
plt.xticks(gas.Year[::3].tolist())
plt.show()
plt.savefig('gas-price-analysis.png', dpi=300)
