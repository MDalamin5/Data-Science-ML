# %%
import pandas as pd

# %%
drinks = pd.read_csv('data/drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.sort_values(by='continent')
# Out:
#         country  beer_servings  spirit_servings  wine_servings  \
# 96      Liberia             19              152              2
# 104        Mali              5                1              1
# 101      Malawi              8               11              1
# 100  Madagascar             26               15              4
# 97        Libya              0                0              0
# ..          ...            ...              ...            ...
# 23       Brazil            245              145             16
# 37     Colombia            159               76              3
# 6     Argentina            193               25            221
# 185     Uruguay            115               35            220
# 20      Bolivia            167               41              8
#
#      total_litres_of_pure_alcohol      continent
# 96                            3.1         Africa
# 104                           0.6         Africa
# 101                           1.5         Africa
# ...

# %%
drinks.sort_values(by='continent', ascending=False)
# Out:
#            country  beer_servings  spirit_servings  wine_servings  \
# 133           Peru            163              160             21
# 72          Guyana             93              302              1
# 23          Brazil            245              145             16
# 188      Venezuela            333              100              3
# 35           Chile            130              124            172
# ..             ...            ...              ...            ...
# 88           Kenya             58               22              2
# 71   Guinea-Bissau             28               31             21
# 70          Guinea              9                0              2
# 66           Ghana             31                3             10
# 192       Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 133                           6.1  South America
# 72                            7.1  South America
# ...

# %%
drinks.sort_values(by=['continent', 'country'], ascending=[True, True])
# Out:
#           country  beer_servings  spirit_servings  wine_servings  \
# 2         Algeria             25                0             14
# 4          Angola            217               57             45
# 18          Benin             34                4             13
# 22       Botswana            173               35             35
# 26   Burkina Faso             25                7              7
# ..            ...            ...              ...            ...
# 132      Paraguay            213              117             74
# 133          Peru            163              160             21
# 163      Suriname            128              178              7
# 185       Uruguay            115               35            220
# 188     Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 2                             0.7         Africa
# 4                             5.9         Africa
# ...

# %%
drinks.sort_values(by=['continent', 'country'], ascending=[True, False])
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 192   Zimbabwe             64               18              4
# 191     Zambia             32               19              4
# 179     Uganda             45                9              0
# 175    Tunisia             51                3             20
# 172       Togo             36                2             19
# ..         ...            ...              ...            ...
# 37    Colombia            159               76              3
# 35       Chile            130              124            172
# 23      Brazil            245              145             16
# 20     Bolivia            167               41              8
# 6    Argentina            193               25            221
#
#      total_litres_of_pure_alcohol      continent
# 192                           4.7         Africa
# 191                           2.5         Africa
# 179                           8.3         Africa
# ...

# %%
drinks.sort_values(by='beer_servings')
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 0       Afghanistan              0                0              0
# 40     Cook Islands              0              254             74
# 79             Iran              0                0              0
# 90           Kuwait              0                0              0
# 97            Libya              0                0              0
# ..              ...            ...              ...            ...
# 135          Poland            343              215             56
# 65          Germany            346              117            175
# 62            Gabon            347               98             59
# 45   Czech Republic            361              170            134
# 117         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0      Asia
# 40                            5.9   Oceania
# ...
