# %%
import pandas as pd

# %%
df = pd.read_csv('job-data.csv')

# %%
# Define salary ranges for each category
salary_ranges = [(0, 30000), (30001, 50000), (50001, 70000), (70001, 90000), (90001, float('inf'))]
categories = ['Low', 'Medium-Low', 'Medium', 'Medium-High', 'High']

# Create a new categorical column based on the salary ranges
def categorize_salary(salary):
    for i, (lower, upper) in enumerate(salary_ranges):
        if lower <= salary <= upper:
            return categories[i]

df['Salary_Category'] = df['Salary'].apply(categorize_salary)

df.tail(3)

# salary_ranges = [(0, 20000), (20001, 40000), (40001, 60000), (60001, 80000), (80001, 100000), (100001, float('inf'))]
# categories = ['Very Low', 'Low', 'Medium-Low', 'Medium-High', 'High', 'Very High']

# # Create a new categorical column based on the salary ranges
# def categorize_salary(salary):
#     for i, (lower, upper) in enumerate(salary_ranges):
#         if lower <= salary <= upper:
#             return categories[i]

# df['Salary_Category'] = df['Salary'].apply(categorize_salary)

# df.tail(3)
# Out:
#     joining_date                      job_title required_experience  \
# 246   02/01/2022  Software Developer (Frontend)   More than 3 years
# 247   01/02/2023           Full Stack Developer   Less than 2 years
# 248   01/02/2022           Full Stack Developer   More than 5 years
#
#     Overall_Satisfication Working_model Considering_Job_Switching_in_Future  \
# 246             Satisfied       On Site                                 Yes
# 247             Satisfied        Remote                                 Yes
# 248             Satisfied        Remote                                 Yes
#
#                Main_Reasons  Salary Salary_Category
# 246  Better salary/benefits   26000             Low
# 247  Better salary/benefits   75000     Medium-High
# 248  Better salary/benefits  110000            High

# %%
# X = df.drop(columns=["joining_date", "Salary", "Salary_Category"])
X = df.drop(columns=["joining_date", "Overall_Satisfication", "Salary", "Salary_Category", ])
X
# Out:
#                                job_title required_experience Working_model  \
# 0    Junior Software Developer (Backend)      Fresh graduate       On Site
# 1                         Data Scientist   More than 2 years        Remote
# 2                         Data Scientist   More than 2 years       On Site
# 3     Senior Software Engineer (Backend)   More than 2 years       On Site
# 4           Software Developer (Backend)   More than 2 years       On Site
# ..                                   ...                 ...           ...
# 244  Software Quality Assurance Engineer      Fresh graduate       On Site
# 245         Software Developer (Backend)   More than 3 years       On Site
# 246        Software Developer (Frontend)   More than 3 years       On Site
# 247                 Full Stack Developer   Less than 2 years        Remote
# 248                 Full Stack Developer   More than 5 years        Remote
#
#     Considering_Job_Switching_in_Future  \
# 0                                    No
# 1                                   Yes
# 2                                   Yes
# 3                                    No
# 4                                   Yes
# ..                                  ...
# 244                                 Yes
# 245                                  No
# 246                                 Yes
# 247                                 Yes
# 248                                 Yes
#
#                                 Main_Reasons
# 0               I am happy with my work role
# 1                     Better salary/benefits
# 2     Career Development, Salary andBenefits
# 3               I am happy with my work role
# 4           Seeking better work-life balance
# ..                                       ...
# 244  Career Development, Salary and Benefits
# 245             I am happy with my work role
# 246                   Better salary/benefits
# 247                   Better salary/benefits
# 248                   Better salary/benefits
#
# [249 rows x 5 columns]

# %%
y = df['Salary_Category']
# y = df['Salary']

# %%
from sklearn.preprocessing import LabelEncoder
le_x = LabelEncoder()
X = X.apply(le_x.fit_transform)
X.head(10)
# Out:
#    job_title  required_experience  Working_model  \
# 0         14                    0              1
# 1          3                    2              2
# 2          3                    2              1
# 3         20                    2              1
# 4         23                    2              1
# 5         10                    2              0
# 6         13                    1              1
# 7         23                    2              1
# 8         24                    1              1
# 9         24                    2              1
#
#    Considering_Job_Switching_in_Future  Main_Reasons
# 0                                    1             4
# 1                                    2             0
# 2                                    2             2
# 3                                    1             4
# 4                                    2             6
# 5                                    2             0
# 6                                    2             2
# 7                                    2             0
# 8                                    2             6
# 9                                    2             0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
my_model = MultinomialNB()
my_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
my_model.score(X_test, y_test)
# Out:
# 0.52
