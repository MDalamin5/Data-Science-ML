# %%
import pandas as pd

# %%
df = pd.read_csv('job-data.csv')
df.head(4)
# Out:
#   joining_date                            job_title required_experience  \
# 0   12/10/2023  Junior Software Developer (Backend)      Fresh graduate
# 1   03/01/2022                       Data Scientist   More than 2 years
# 2   02/06/2022                       Data Scientist   More than 2 years
# 3   01/03/2021   Senior Software Engineer (Backend)   More than 2 years
#
#   Overall_Satisfication Working_model Considering_Job_Switching_in_Future  \
# 0             Satisfied       On Site                                  No
# 1             Satisfied        Remote                                 Yes
# 2             Satisfied       On Site                                 Yes
# 3        Very Satisfied       On Site                                  No
#
#                              Main_Reasons  Salary
# 0            I am happy with my work role   19000
# 1                  Better salary/benefits   50000
# 2  Career Development, Salary andBenefits  115000
# ...

# %%
col_1_df = df.drop(columns=['joining_date', 'job_title', 'Overall_Satisfication', 'Working_model', 'Considering_Job_Switching_in_Future', 'Main_Reasons'], axis=1)
col_1_df
# Out:
#     required_experience  Salary
# 0        Fresh graduate   19000
# 1     More than 2 years   50000
# 2     More than 2 years  115000
# 3     More than 2 years  100000
# 4     More than 2 years   47000
# ..                  ...     ...
# 244      Fresh graduate    7000
# 245   More than 3 years   80000
# 246   More than 3 years   26000
# 247   Less than 2 years   75000
# 248   More than 5 years  110000
#
# [249 rows x 2 columns]

# %%
X = col_1_df.drop('Salary', axis=1)
X
# Out:
#     required_experience
# 0        Fresh graduate
# 1     More than 2 years
# 2     More than 2 years
# 3     More than 2 years
# 4     More than 2 years
# ..                  ...
# 244      Fresh graduate
# 245   More than 3 years
# 246   More than 3 years
# 247   Less than 2 years
# 248   More than 5 years
#
# [249 rows x 1 columns]

# %%
y = col_1_df.Salary
y.head(2)
# Out:
# 0    19000
# 1    50000
# Name: Salary, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
le_en = LabelEncoder()

# %%
X = X.apply(le_en.fit_transform)
X.head(5)
# Out:
#    required_experience
# 0                    0
# 1                    2
# 2                    2
# 3                    2
# 4                    2

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
my_model = LinearRegression()
my_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
my_model.score(X_test, y_test)
# Out:
# 0.6302119424992783

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# %%
result = cross_val_score(DecisionTreeClassifier(), X, y, cv=5)
result
# Out:
# c:\Users\Lenovo\anaconda3\envs\MY_LOQ\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# array([0.12      , 0.14      , 0.04      , 0.1       , 0.14285714])

# %%
from sklearn.neighbors import KNeighborsClassifier
result = cross_val_score(KNeighborsClassifier(n_neighbors=3), X, y, cv=5)
result
# Out:
# c:\Users\Lenovo\anaconda3\envs\MY_LOQ\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# array([0.06      , 0.04      , 0.04      , 0.02      , 0.06122449])
