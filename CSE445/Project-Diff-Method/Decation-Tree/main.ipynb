# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('job-data.csv')
df.head(3)
# Out:
#   joining_date                            job_title required_experience  \
# 0   12/10/2023  Junior Software Developer (Backend)      Fresh graduate
# 1   03/01/2022                       Data Scientist   More than 2 years
# 2   02/06/2022                       Data Scientist   More than 2 years
#
#   Overall_Satisfication Working_model Considering_Job_Switching_in_Future  \
# 0             Satisfied       On Site                                  No
# 1             Satisfied        Remote                                 Yes
# 2             Satisfied       On Site                                 Yes
#
#                              Main_Reasons  Salary
# 0            I am happy with my work role   19000
# 1                  Better salary/benefits   50000
# 2  Career Development, Salary andBenefits  115000

# %%
df.describe()
# Out:
#               Salary
# count     249.000000
# mean    64496.987952
# std     41186.721271
# min      5000.000000
# 25%     35000.000000
# 50%     55000.000000
# 75%     85000.000000
# max    200000.000000

# %%
df.isnull().sum()
# Out:
# joining_date                           0
# job_title                              0
# required_experience                    0
# Overall_Satisfication                  0
# Working_model                          0
# Considering_Job_Switching_in_Future    0
# Main_Reasons                           0
# Salary                                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   joining_date                         249 non-null    object
#  1   job_title                            249 non-null    object
#  2   required_experience                  249 non-null    object
#  3   Overall_Satisfication                249 non-null    object
#  4   Working_model                        249 non-null    object
#  5   Considering_Job_Switching_in_Future  249 non-null    object
#  6   Main_Reasons                         249 non-null    object
#  7   Salary                               249 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 15.7+ KB

# %%
df.drop(columns=['joining_date'], inplace=True)
df.head(2)
# Out:
#                              job_title required_experience  \
# 0  Junior Software Developer (Backend)      Fresh graduate
# 1                       Data Scientist   More than 2 years
#
#   Overall_Satisfication Working_model Considering_Job_Switching_in_Future  \
# 0             Satisfied       On Site                                  No
# 1             Satisfied        Remote                                 Yes
#
#                    Main_Reasons  Salary
# 0  I am happy with my work role   19000
# 1        Better salary/benefits   50000

# %%
x = df.drop('Salary', axis=1)

# %%
x
# Out:
#                                job_title required_experience  \
# 0    Junior Software Developer (Backend)      Fresh graduate
# 1                         Data Scientist   More than 2 years
# 2                         Data Scientist   More than 2 years
# 3     Senior Software Engineer (Backend)   More than 2 years
# 4           Software Developer (Backend)   More than 2 years
# ..                                   ...                 ...
# 244  Software Quality Assurance Engineer      Fresh graduate
# 245         Software Developer (Backend)   More than 3 years
# 246        Software Developer (Frontend)   More than 3 years
# 247                 Full Stack Developer   Less than 2 years
# 248                 Full Stack Developer   More than 5 years
#
#     Overall_Satisfication Working_model Considering_Job_Switching_in_Future  \
# 0               Satisfied       On Site                                  No
# 1               Satisfied        Remote                                 Yes
# 2               Satisfied       On Site                                 Yes
# 3          Very Satisfied       On Site                                  No
# 4               Satisfied       On Site                                 Yes
# ..                    ...           ...                                 ...
# 244               Neutral       On Site                                 Yes
# 245             Satisfied       On Site                                  No
# 246             Satisfied       On Site                                 Yes
# 247             Satisfied        Remote                                 Yes
# 248             Satisfied        Remote                                 Yes
#
#                                 Main_Reasons
# 0               I am happy with my work role
# 1                     Better salary/benefits
# 2     Career Development, Salary andBenefits
# 3               I am happy with my work role
# 4           Seeking better work-life balance
# ..                                       ...
# 244  Career Development, Salary and Benefits
# 245             I am happy with my work role
# 246                   Better salary/benefits
# 247                   Better salary/benefits
# 248                   Better salary/benefits
#
# [249 rows x 6 columns]

# %%
y = df.Salary
y
# Out:
# 0       19000
# 1       50000
# 2      115000
# 3      100000
# 4       47000
#         ...
# 244      7000
# 245     80000
# 246     26000
# 247     75000
# 248    110000
# Name: Salary, Length: 249, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_x = LabelEncoder()
x = x.apply(le_x.fit_transform)

# %%
x
# Out:
#      job_title  required_experience  Overall_Satisfication  Working_model  \
# 0           14                    0                      2              1
# 1            3                    2                      2              2
# 2            3                    2                      2              1
# 3           20                    2                      3              1
# 4           23                    2                      2              1
# ..         ...                  ...                    ...            ...
# 244         28                    0                      1              1
# 245         23                    3                      2              1
# 246         24                    3                      2              1
# 247          9                    1                      2              2
# 248          9                    5                      2              2
#
#      Considering_Job_Switching_in_Future  Main_Reasons
# 0                                      1             4
# 1                                      2             0
# 2                                      2             2
# 3                                      1             4
# 4                                      2             6
# ..                                   ...           ...
# 244                                    2             1
# 245                                    1             4
# 246                                    2             0
# 247                                    2             0
# 248                                    2             0
#
# [249 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.2, random_state= 42)

# %%
xtrain
# Out:
#      job_title  required_experience  Overall_Satisfication  Working_model  \
# 132         28                    2                      2              1
# 156         18                    2                      1              1
# 213         18                    8                      2              1
# 119         24                    0                      2              1
# 139          0                    3                      2              1
# ..         ...                  ...                    ...            ...
# 106         24                    0                      2              2
# 14           4                    3                      2              1
# 92          26                    6                      2              2
# 179         12                    2                      2              1
# 102         31                    0                      1              1
#
#      Considering_Job_Switching_in_Future  Main_Reasons
# 132                                    2             1
# 156                                    2             0
# 213                                    1             4
# 119                                    2             3
# 139                                    1             4
# ..                                   ...           ...
# 106                                    1             4
# 14                                     2             0
# 92                                     1             4
# 179                                    2             0
# 102                                    2             1
#
# [199 rows x 6 columns]

# %%
ytrain
# Out:
# 132     42000
# 156     45000
# 213    150000
# 119     20000
# 139    170000
#         ...
# 106     10000
# 14     100000
# 92     170000
# 179    100000
# 102     15000
# Name: Salary, Length: 199, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
dect = DecisionTreeClassifier()
dect.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dect.predict(xtest)
# Out:
# array([ 80000,  12000,  90000,  65000,   7000,  60000,  75000, 120000,
#         48000,  32000,  75000,  80000,  80000,  10000,  45000, 135000,
#         40000,  75000,  28000,  37000,  70000, 100000, 100000,  60000,
#        105000,  40000,  12000, 100000,  45000,  35000,  45000,  32500,
#         35000, 155000,  30000,   7000,  45000,  30000,  70000,  15000,
#         12000,  25000,  70000,   7000, 170000,  80000,  50000,  47000,
#         32000,  15000])

# %%
dect.score(xtest, ytest)
# Out:
# 0.14
