# %%
import pandas as pd

# %%
df = pd.read_csv('job-data.csv')

# %%
df.head(3)
# Out:
#   joining_date                           job_title required_experience  \
# 0   12/10/2023  Junior Software Developer(Backend)      Fresh graduate
# 1   03/01/2022                      Data Scientist   More than 2 years
# 2   02/06/2022                      Data Scientist   More than 2 years
#
#   Overall_Satisfication Working_model Considering_Job_Switching_in_Future  \
# 0             Satisfied       On Site                                  No
# 1             Satisfied        Remote                                 Yes
# 2             Satisfied       On Site                                 Yes
#
#                               Main_Reasons  Salary
# 0             I am happy with my work role   19000
# 1                   Better salary/benefits   50000
# 2  Career Development, Salary and Benefits  115000

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Salary', axis=1)
y = df.Salary

# %%
le_x = LabelEncoder()
X = X.apply(le_x.fit_transform)

# %%
X
# Out:
#      joining_date  job_title  required_experience  Overall_Satisfication  \
# 0             149         19                    0                      2
# 1              36          5                    6                      2
# 2              30          5                    6                      2
# 3              13         31                    6                      4
# 4              40         33                    6                      2
# ..            ...        ...                  ...                    ...
# 538           172         30                   15                      4
# 539           187         27                   14                      1
# 540           122         41                    6                      4
# 541           160         21                    0                      2
# 542           199          5                    3                      2
#
#      Working_model  Considering_Job_Switching_in_Future  Main_Reasons
# 0                1                                    0             4
# 1                2                                    1             0
# 2                1                                    1             1
# 3                1                                    0             4
# 4                1                                    1             6
# ..             ...                                  ...           ...
# 538              1                                    1             2
# 539              0                                    1             0
# 540              1                                    1             2
# 541              0                                    0             4
# 542              2                                    0             4
#
# [543 rows x 7 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33)

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC(kernel='rbf', C=1, gamma='auto')
svm_model.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma='auto')

# %%
svm_model.score(X_test, y_test)
# Out:
# 0.36764705882352944

# %% [markdown]
# ### Fine Tuning and find best parameter for SVM, using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(SVC(gamma='auto'), {
    'C' : [1, 10, 20, 30],
    'kernel' : ['rbf', 'linear', 'poly']
}, cv=5)

clf.fit(X, y)
clf.cv_results_
# Out:
# c:\Users\Lenovo\anaconda3\envs\MY_LOQ\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# {'mean_fit_time': array([6.52830124e-02, 2.06131454e+00, 1.01443203e+03, 7.68259525e-02,
#         1.25427284e+01, 1.11910266e+03, 5.81560612e-02, 1.85222070e+01,
#         1.21472834e+03, 6.19801044e-02, 2.75802248e+01, 1.20213020e+03]),
#  'std_fit_time': array([1.37962331e-02, 3.28700171e-01, 5.64527280e+02, 9.96096326e-03,
#         3.18118116e+00, 6.57156381e+02, 6.58917819e-03, 4.47232706e+00,
#         6.77247315e+02, 2.87915147e-03, 5.61894696e+00, 7.00947186e+02]),
#  'mean_score_time': array([0.00897985, 0.01073437, 0.00862579, 0.01178994, 0.00994663,
#         0.00862837, 0.01089697, 0.00799336, 0.00760307, 0.0079793 ,
#         0.01080422, 0.00762644]),
#  'std_score_time': array([0.00112121, 0.0033946 , 0.00206503, 0.00113633, 0.0037204 ,
#         0.00282371, 0.00365626, 0.00567417, 0.00163839, 0.00447849,
#         0.00408584, 0.00206441]),
#  'param_C': masked_array(data=[1, 1, 1, 10, 10, 10, 20, 20, 20, 30, 30, 30],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'poly', 'rbf', 'linear', 'poly',
#                     'rbf', 'linear', 'poly', 'rbf', 'linear', 'poly'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'poly'},
#   {'C': 30, 'kernel': 'rbf'},
#   {'C': 30, 'kernel': 'linear'},
#   {'C': 30, 'kernel': 'poly'}],
#  'split0_test_score': array([0.23853211, 0.12844037, 0.2293578 , 0.25688073, 0.1559633 ,
#         0.2293578 , 0.25688073, 0.18348624, 0.2293578 , 0.25688073,
#         0.18348624, 0.2293578 ]),
#  'split1_test_score': array([0.18348624, 0.19266055, 0.13761468, 0.21100917, 0.16513761,
#         0.13761468, 0.21100917, 0.16513761, 0.13761468, 0.21100917,
#         0.16513761, 0.13761468]),
#  'split2_test_score': array([0.33027523, 0.26605505, 0.32110092, 0.36697248, 0.26605505,
#         0.32110092, 0.36697248, 0.27522936, 0.32110092, 0.36697248,
#         0.28440367, 0.32110092]),
#  'split3_test_score': array([0.34259259, 0.22222222, 0.34259259, 0.35185185, 0.26851852,
#         0.34259259, 0.35185185, 0.27777778, 0.34259259, 0.35185185,
#         0.2962963 , 0.34259259]),
#  'split4_test_score': array([0.50925926, 0.28703704, 0.49074074, 0.53703704, 0.28703704,
#         0.49074074, 0.53703704, 0.2962963 , 0.49074074, 0.53703704,
#         0.2962963 , 0.49074074]),
#  'mean_test_score': array([0.32082909, 0.21928304, 0.30428135, 0.34475025, 0.2285423 ,
#         0.30428135, 0.34475025, 0.23958546, 0.30428135, 0.34475025,
#         0.24512402, 0.30428135]),
#  'std_test_score': array([0.11108975, 0.05612132, 0.11824472, 0.11236209, 0.05606211,
#         0.11824472, 0.11236209, 0.0541015 , 0.11824472, 0.11236209,
#         0.05827029, 0.11824472]),
#  'rank_test_score': array([ 4, 12,  5,  1, 11,  5,  1, 10,  5,  1,  9,  5])}

# %%
new_df = pd.DataFrame(clf.cv_results_)
new_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.065283      0.013796         0.008980        0.001121       1
# 1        2.061315      0.328700         0.010734        0.003395       1
# 2     1014.432029    564.527280         0.008626        0.002065       1
# 3        0.076826      0.009961         0.011790        0.001136      10
# 4       12.542728      3.181181         0.009947        0.003720      10
# 5     1119.102662    657.156381         0.008628        0.002824      10
# 6        0.058156      0.006589         0.010897        0.003656      20
# 7       18.522207      4.472327         0.007993        0.005674      20
# 8     1214.728337    677.247315         0.007603        0.001638      20
# 9        0.061980      0.002879         0.007979        0.004478      30
# 10      27.580225      5.618947         0.010804        0.004086      30
# 11    1202.130203    700.947186         0.007626        0.002064      30
#
#    param_kernel                         params  split0_test_score  \
# 0           rbf      {'C': 1, 'kernel': 'rbf'}           0.238532
# 1        linear   {'C': 1, 'kernel': 'linear'}           0.128440
# 2          poly     {'C': 1, 'kernel': 'poly'}           0.229358
# 3           rbf     {'C': 10, 'kernel': 'rbf'}           0.256881
# 4        linear  {'C': 10, 'kernel': 'linear'}           0.155963
# 5          poly    {'C': 10, 'kernel': 'poly'}           0.229358
# 6           rbf     {'C': 20, 'kernel': 'rbf'}           0.256881
# 7        linear  {'C': 20, 'kernel': 'linear'}           0.183486
# 8          poly    {'C': 20, 'kernel': 'poly'}           0.229358
# 9           rbf     {'C': 30, 'kernel': 'rbf'}           0.256881
# 10       linear  {'C': 30, 'kernel': 'linear'}           0.183486
# 11         poly    {'C': 30, 'kernel': 'poly'}           0.229358
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.183486           0.330275           0.342593
# 1            0.192661           0.266055           0.222222
# 2            0.137615           0.321101           0.342593
# 3            0.211009           0.366972           0.351852
# 4            0.165138           0.266055           0.268519
# 5            0.137615           0.321101           0.342593
# 6            0.211009           0.366972           0.351852
# 7            0.165138           0.275229           0.277778
# 8            0.137615           0.321101           0.342593
# 9            0.211009           0.366972           0.351852
# 10           0.165138           0.284404           0.296296
# 11           0.137615           0.321101           0.342593
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.509259         0.320829        0.111090                4
# 1            0.287037         0.219283        0.056121               12
# 2            0.490741         0.304281        0.118245                5
# 3            0.537037         0.344750        0.112362                1
# 4            0.287037         0.228542        0.056062               11
# 5            0.490741         0.304281        0.118245                5
# 6            0.537037         0.344750        0.112362                1
# 7            0.296296         0.239585        0.054102               10
# 8            0.490741         0.304281        0.118245                5
# 9            0.537037         0.344750        0.112362                1
# 10           0.296296         0.245124        0.058270                9
# 11           0.490741         0.304281        0.118245                5

# %%
clf.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
clf.best_score_
# Out:
# 0.34475025484199795

# %%
svm_model_updated = SVC(kernel='rbf', C=10, gamma='auto')
svm_model_updated.fit(X_train, y_train)
svm_model_updated.score(X_test, y_test)
# Out:
# 0.39705882352941174
