# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
# Load the data
df = pd.read_csv('job-data.csv')

# Exclude "joining_date" column
df_exclude_date = df.drop(columns=["joining_date"])

# Perform one-hot encoding for categorical variables
df_encoded = pd.get_dummies(df_exclude_date, columns=["job_title", "required_experience", "Overall_Satisfication", "Working_model", "Considering_Job_Switching_in_Future", "Main_Reasons"])

# Separate features (X) and target variable (y)
X = df_encoded.drop(columns=["Salary"])
y = df_encoded["Salary"]

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)

from sklearn.neighbors import KNeighborsRegressor
# Build the KNN regression model
k = 5  # Number of neighbors
knn_model = KNeighborsRegressor(n_neighbors=k)
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knn_model.score(X_test, y_test)
# Out:
# 0.5302800205659668

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsRegressor
result = cross_val_score(KNeighborsRegressor(n_neighbors=3), X, y, cv=5)
result
# Out:
# array([0.55801562, 0.25910541, 0.02321044, 0.74648715, 0.47646873])

# %%
result.mean()
# Out:
# 0.41265747064532876

# %%
X_train
# Out:
#      job_title_Artificial Intelligence (AI) Engineer  job_title_CEO  \
# 122                                            False          False
# 275                                            False          False
# 98                                             False          False
# 432                                            False          False
# 333                                            False          False
# ..                                               ...            ...
# 195                                            False          False
# 57                                             False          False
# 201                                            False          False
# 391                                            False          False
# 20                                             False          False
#
#      job_title_Cloud Engineer  job_title_Cybersecurity Specialist  \
# 122                     False                               False
# 275                     False                               False
# 98                      False                               False
# 432                     False                               False
# 333                     False                               False
# ..                        ...                                 ...
# 195                     False                               False
# 57                      False                               False
# 201                     False                               False
# 391                     False                                True
# 20                      False                               False
#
#      job_title_Data Analyst  job_title_Data Scientist  \
# 122                   False                     False
# 275                   False                     False
# 98                    False                     False
# 432                   False                     False
# 333                   False                     False
# ..                      ...                       ...
# 195                   False                     False
# 57                    False                     False
# 201                   False                     False
# 391                   False                     False
# 20                    False                     False
#
#      job_title_Database Administrator (DBA)  job_title_DevOps Engineer  \
# 122                                   False                      False
# 275                                   False                      False
# 98                                    False                      False
# 432                                   False                      False
# 333                                   False                      False
# ..                                      ...                        ...
# 195                                   False                      False
# 57                                    False                      False
# 201                                   False                      False
# 391                                   False                      False
# 20                                    False                       True
#
#      job_title_Digital Marketing  job_title_EEE Engineer  ...  \
# 122                        False                   False  ...
# 275                        False                   False  ...
# 98                         False                   False  ...
# 432                        False                   False  ...
# 333                        False                   False  ...
# ..                           ...                     ...  ...
# 195                        False                   False  ...
# 57                         False                   False  ...
# 201                        False                   False  ...
# 391                        False                   False  ...
# 20                         False                   False  ...
#
#      Working_model_Remote  Considering_Job_Switching_in_Future_No  \
# 122                  True                                   False
# 275                 False                                   False
# 98                  False                                   False
# 432                 False                                    True
# 333                 False                                   False
# ..                    ...                                     ...
# 195                 False                                   False
# 57                   True                                   False
# 201                 False                                    True
# 391                 False                                    True
# 20                   True                                   False
#
#      Considering_Job_Switching_in_Future_Yes  \
# 122                                     True
# 275                                     True
# 98                                      True
# 432                                    False
# 333                                     True
# ..                                       ...
# 195                                     True
# 57                                      True
# 201                                    False
# 391                                    False
# 20                                      True
#
#      Main_Reasons_Better salary/benefits  \
# 122                                 True
# 275                                 True
# 98                                  True
# 432                                False
# 333                                False
# ..                                   ...
# 195                                 True
# 57                                  True
# 201                                False
# 391                                False
# 20                                 False
#
#      Main_Reasons_Career Development, Salary and Benefits  \
# 122                                              False
# 275                                              False
# 98                                               False
# 432                                              False
# 333                                              False
# ..                                                 ...
# 195                                              False
# 57                                               False
# 201                                              False
# 391                                              False
# 20                                               False
#
#      Main_Reasons_Career advancement opportunities  \
# 122                                          False
# 275                                          False
# 98                                           False
# 432                                          False
# 333                                          False
# ..                                             ...
# 195                                          False
# 57                                           False
# 201                                          False
# 391                                          False
# 20                                            True
#
#      Main_Reasons_Dissatisfaction with previous job role/environment  \
# 122                                              False
# 275                                              False
# 98                                               False
# 432                                              False
# 333                                              False
# ..                                                 ...
# 195                                              False
# 57                                               False
# 201                                              False
# 391                                              False
# 20                                               False
#
#      Main_Reasons_I am happy with my work role  \
# 122                                      False
# 275                                      False
# 98                                       False
# 432                                       True
# 333                                      False
# ..                                         ...
# 195                                      False
# 57                                       False
# 201                                       True
# 391                                       True
# 20                                       False
#
#      Main_Reasons_Relocation/move to a different city  \
# 122                                             False
# 275                                             False
# 98                                              False
# 432                                             False
# 333                                             False
# ..                                                ...
# 195                                             False
# 57                                              False
# 201                                             False
# 391                                             False
# 20                                              False
#
#      Main_Reasons_Seeking better work-life balance
# 122                                          False
# 275                                          False
# 98                                           False
# 432                                          False
# 333                                           True
# ..                                             ...
# 195                                          False
# 57                                           False
# 201                                          False
# 391                                          False
# 20                                           False
#
# [434 rows x 82 columns]
