# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.sort_values(['HP'], ascending=True)
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 139  129   Magikarp    Water    NaN    200   20      10       55       15
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 487  439   Mime Jr.  Psychic  Fairy    310   20      25       45       70
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Test'] = df['HP'] + df['Attack']

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df = df.drop(columns=['Test'])
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df['Test'] = df.iloc[:, 5:11].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
cols = list(df.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Test']

# %%
df = df[cols[0:5] + [cols[-1]] + [cols[-2]] + cols[5:11]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Test  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318   318      False  45
# 1      2                Ivysaur    Grass  Poison    405   405      False  60
# 2      3               Venusaur    Grass  Poison    525   525      False  80
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   625      False  80
# 4      4             Charmander     Fire     NaN    309   309      False  39
# ..   ...                    ...      ...     ...    ...   ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600   600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700   700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   680       True  80
# 799  721              Volcanion     Fire   Water    600   600       True  80
#
# ...

# %%
df.to_csv('data/mod_file.csv')

# %%
df.to_excel('data/mod_file.xlsx')

# %%
df.to_csv('data/mod_file.txt', sep='\t')

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] >= 70)]
# Out:
#        #                   Name Type 1  Type 2  Total  Test  Legendary   HP  \
# 2      3               Venusaur  Grass  Poison    525   525      False   80
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   625      False   80
# 50    45              Vileplume  Grass  Poison    490   490      False   75
# 77    71             Victreebel  Grass  Poison    490   490      False   80
# 652  591              Amoonguss  Grass  Poison    464   464      False  114
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed
# 2        82       83      100      100     80
# 3       100      123      122      120     80
# 50       80       85      110       90     50
# 77      105       65      100       70     70
# 652      85       70       85       80     30

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] >= 70)]
new_df
# Out:
#        #                   Name Type 1  Type 2  Total  Test  Legendary   HP  \
# 2      3               Venusaur  Grass  Poison    525   525      False   80
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   625      False   80
# 50    45              Vileplume  Grass  Poison    490   490      False   75
# 77    71             Victreebel  Grass  Poison    490   490      False   80
# 652  591              Amoonguss  Grass  Poison    464   464      False  114
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed
# 2        82       83      100      100     80
# 3       100      123      122      120     80
# 50       80       85      110       90     50
# 77      105       65      100       70     70
# 652      85       70       85       80     30

# %%
new_df = new_df.reset_index()
new_df
# Out:
#    index    #                   Name Type 1  Type 2  Total  Test  Legendary  \
# 0      2    3               Venusaur  Grass  Poison    525   525      False
# 1      3    3  VenusaurMega Venusaur  Grass  Poison    625   625      False
# 2     50   45              Vileplume  Grass  Poison    490   490      False
# 3     77   71             Victreebel  Grass  Poison    490   490      False
# 4    652  591              Amoonguss  Grass  Poison    464   464      False
#
#     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0   80      82       83      100      100     80
# 1   80     100      123      122      120     80
# 2   75      80       85      110       90     50
# 3   80     105       65      100       70     70
# 4  114      85       70       85       80     30

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Test  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318   318      False  45
# 1      2                Ivysaur    Grass  Poison    405   405      False  60
# 2      3               Venusaur    Grass  Poison    525   525      False  80
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   625      False  80
# 4      4             Charmander     Fire     NaN    309   309      False  39
# ..   ...                    ...      ...     ...    ...   ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600   600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700   700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   680       True  80
# 799  721              Volcanion     Fire   Water    600   600       True  80
#
# ...

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass')]
# Out:
#        #                   Name Type 1  Type 2  Total  Test  Legendary   HP  \
# 0      1              Bulbasaur  Grass  Poison    318   318      False   45
# 1      2                Ivysaur  Grass  Poison    405   405      False   60
# 2      3               Venusaur  Grass  Poison    525   525      False   80
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   625      False   80
# 4      4             Charmander   Fire     NaN    309   309      False   39
# ..   ...                    ...    ...     ...    ...   ...        ...  ...
# 735  667                 Litleo   Fire  Normal    369   369      False   62
# 736  668                 Pyroar   Fire  Normal    507   507      False   86
# 740  672                 Skiddo  Grass     NaN    350   350      False   66
# 741  673                 Gogoat  Grass     NaN    531   531      False  123
# 799  721              Volcanion   Fire   Water    600   600       True   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
import re

# %%
df.loc[df['Type 1'].str.contains('fire|grass' , flags= re.I) ]
# Out:
#        #                   Name Type 1  Type 2  Total  Test  Legendary   HP  \
# 0      1              Bulbasaur  Grass  Poison    318   318      False   45
# 1      2                Ivysaur  Grass  Poison    405   405      False   60
# 2      3               Venusaur  Grass  Poison    525   525      False   80
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   625      False   80
# 4      4             Charmander   Fire     NaN    309   309      False   39
# ..   ...                    ...    ...     ...    ...   ...        ...  ...
# 735  667                 Litleo   Fire  Normal    369   369      False   62
# 736  668                 Pyroar   Fire  Normal    507   507      False   86
# 740  672                 Skiddo  Grass     NaN    350   350      False   66
# 741  673                 Gogoat  Grass     NaN    531   531      False  123
# 799  721              Volcanion   Fire   Water    600   600       True   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.loc[df['Type 1']=='Fire', 'Type 1'] = 'Agunn'
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Test  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318   318      False  45
# 1      2                Ivysaur    Grass  Poison    405   405      False  60
# 2      3               Venusaur    Grass  Poison    525   525      False  80
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   625      False  80
# 4      4             Charmander    Agunn     NaN    309   309      False  39
# ..   ...                    ...      ...     ...    ...   ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600   600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700   700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   680       True  80
# 799  721              Volcanion    Agunn   Water    600   600       True  80
#
# ...

# %%
df.loc[df['Type 1'] == 'Grass', 'HP'] = 69
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Test  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318   318      False  69
# 1      2                Ivysaur    Grass  Poison    405   405      False  69
# 2      3               Venusaur    Grass  Poison    525   525      False  69
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   625      False  69
# 4      4             Charmander    Agunn     NaN    309   309      False  39
# ..   ...                    ...      ...     ...    ...   ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600   600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700   700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   680       True  80
# 799  721              Volcanion    Agunn   Water    600   600       True  80
#
# ...

# %%
df.loc[df['Total'] >= 500, ['HP', 'Attack']] = 0
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Test  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318   318      False  69
# 1      2                Ivysaur    Grass  Poison    405   405      False  69
# 2      3               Venusaur    Grass  Poison    525   525      False   0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   625      False   0
# 4      4             Charmander    Agunn     NaN    309   309      False  39
# ..   ...                    ...      ...     ...    ...   ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600   600       True   0
# 796  719    DiancieMega Diancie     Rock   Fairy    700   700       True   0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   600       True   0
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   680       True   0
# 799  721              Volcanion    Agunn   Water    600   600       True   0
#
# ...

# %%
df.loc[df['Total'] >= 500, ['HP', 'Attack']] = ['1', '99']
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Test  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318   318      False  69
# 1      2                Ivysaur    Grass  Poison    405   405      False  69
# 2      3               Venusaur    Grass  Poison    525   525      False   1
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   625      False   1
# 4      4             Charmander    Agunn     NaN    309   309      False  39
# ..   ...                    ...      ...     ...    ...   ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600   600       True   1
# 796  719    DiancieMega Diancie     Rock   Fairy    700   700       True   1
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   600       True   1
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   680       True   1
# 799  721              Volcanion    Agunn   Water    600   600       True   1
#
#     Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...
