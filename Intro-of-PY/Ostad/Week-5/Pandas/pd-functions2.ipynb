# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.sort_values(['HP'], ascending=True)
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 139  129   Magikarp    Water    NaN    200   20      10       55       15
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 487  439   Mime Jr.  Psychic  Fairy    310   20      25       45       70
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Test'] = df['HP'] + df['Attack']

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df = df.drop(columns=['Test'])
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df['Test'] = df.iloc[:, 5:11].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
cols = list(df.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Test']

# %%
df = df[cols[0:5] + [cols[-1]] + [cols[-2]] + cols[5:11]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Test  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318   318      False  45
# 1      2                Ivysaur    Grass  Poison    405   405      False  60
# 2      3               Venusaur    Grass  Poison    525   525      False  80
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   625      False  80
# 4      4             Charmander     Fire     NaN    309   309      False  39
# ..   ...                    ...      ...     ...    ...   ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600   600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700   700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   680       True  80
# 799  721              Volcanion     Fire   Water    600   600       True  80
#
# ...

# %%
df.to_csv('data/mod_file.csv')

# %%
df.to_excel('data/mod_file.xlsx')

# %%
df.to_csv('data/mod_file.txt', sep='\t')

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] >= 70)]
# Out:
#        #                   Name Type 1  Type 2  Total  Test  Legendary   HP  \
# 2      3               Venusaur  Grass  Poison    525   525      False   80
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   625      False   80
# 50    45              Vileplume  Grass  Poison    490   490      False   75
# 77    71             Victreebel  Grass  Poison    490   490      False   80
# 652  591              Amoonguss  Grass  Poison    464   464      False  114
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed
# 2        82       83      100      100     80
# 3       100      123      122      120     80
# 50       80       85      110       90     50
# 77      105       65      100       70     70
# 652      85       70       85       80     30

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] >= 70)]
new_df
# Out:
#        #                   Name Type 1  Type 2  Total  Test  Legendary   HP  \
# 2      3               Venusaur  Grass  Poison    525   525      False   80
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   625      False   80
# 50    45              Vileplume  Grass  Poison    490   490      False   75
# 77    71             Victreebel  Grass  Poison    490   490      False   80
# 652  591              Amoonguss  Grass  Poison    464   464      False  114
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed
# 2        82       83      100      100     80
# 3       100      123      122      120     80
# 50       80       85      110       90     50
# 77      105       65      100       70     70
# 652      85       70       85       80     30

# %%
new_df = new_df.reset_index()
new_df
# Out:
#    level_0  index    #                   Name Type 1  Type 2  Total  Test  \
# 0        0      2    3               Venusaur  Grass  Poison    525   525
# 1        1      3    3  VenusaurMega Venusaur  Grass  Poison    625   625
# 2        2     50   45              Vileplume  Grass  Poison    490   490
# 3        3     77   71             Victreebel  Grass  Poison    490   490
# 4        4    652  591              Amoonguss  Grass  Poison    464   464
#
#    Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      False   80      82       83      100      100     80
# 1      False   80     100      123      122      120     80
# 2      False   75      80       85      110       90     50
# 3      False   80     105       65      100       70     70
# 4      False  114      85       70       85       80     30

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Test  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318   318      False  45
# 1      2                Ivysaur    Grass  Poison    405   405      False  60
# 2      3               Venusaur    Grass  Poison    525   525      False  80
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   625      False  80
# 4      4             Charmander     Fire     NaN    309   309      False  39
# ..   ...                    ...      ...     ...    ...   ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600   600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700   700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   680       True  80
# 799  721              Volcanion     Fire   Water    600   600       True  80
#
# ...

# %%
# Selecting only the numeric columns
numeric_cols = df.select_dtypes(include='number')

# Grouping by 'Type 1' and calculating the mean of numerical columns
mean_by_type1 = numeric_cols.groupby(df['Type 1']).mean()

mean_by_type1
# Out:
#                    #       Total        Test         HP      Attack  \
# Type 1
# Bug       334.492754  378.927536  378.927536  56.884058   70.971014
# Dark      461.354839  445.741935  445.741935  66.806452   88.387097
# Dragon    474.375000  550.531250  550.531250  83.312500  112.125000
# Electric  363.500000  443.409091  443.409091  59.795455   69.090909
# Fairy     449.529412  413.176471  413.176471  74.117647   61.529412
# Fighting  363.851852  416.444444  416.444444  69.851852   96.777778
# Fire      327.403846  458.076923  458.076923  69.903846   84.769231
# Flying    677.750000  485.000000  485.000000  70.750000   78.750000
# Ghost     486.500000  439.562500  439.562500  64.437500   73.781250
# Grass     344.871429  421.142857  421.142857  67.271429   73.214286
# Ground    356.281250  437.500000  437.500000  73.781250   95.750000
# Ice       423.541667  433.458333  433.458333  72.000000   72.750000
# Normal    319.173469  401.683673  401.683673  77.275510   73.469388
# ...

# %%
numeric_cols.groupby(df['Type 1']).mean().sort_values('Defense', ascending=True)
# Out:
#                    #       Total        Test         HP      Attack  \
# Type 1
# Normal    319.173469  401.683673  401.683673  77.275510   73.469388
# Fairy     449.529412  413.176471  413.176471  74.117647   61.529412
# Fighting  363.851852  416.444444  416.444444  69.851852   96.777778
# Flying    677.750000  485.000000  485.000000  70.750000   78.750000
# Electric  363.500000  443.409091  443.409091  59.795455   69.090909
# Psychic   380.807018  475.947368  475.947368  70.631579   71.456140
# Fire      327.403846  458.076923  458.076923  69.903846   84.769231
# Poison    251.785714  399.142857  399.142857  67.250000   74.678571
# Dark      461.354839  445.741935  445.741935  66.806452   88.387097
# Bug       334.492754  378.927536  378.927536  56.884058   70.971014
# Grass     344.871429  421.142857  421.142857  67.271429   73.214286
# Ice       423.541667  433.458333  433.458333  72.000000   72.750000
# Water     303.089286  430.455357  430.455357  72.062500   74.151786
# ...

# %%
numeric_cols.groupby(df['Type 1']).sum()
# Out:
#               #  Total   Test    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Type 1
# Bug       23080  26146  26146  3925    4897     4880     3717     4471   4256
# Dark      14302  13818  13818  2071    2740     2177     2314     2155   2361
# Dragon    15180  17617  17617  2666    3588     2764     3099     2843   2657
# Electric  15994  19510  19510  2631    3040     2917     3961     3243   3718
# Fairy      7642   7024   7024  1260    1046     1117     1335     1440    826
# Fighting   9824  11244  11244  1886    2613     1780     1434     1747   1784
# Fire      17025  23820  23820  3635    4408     3524     4627     3755   3871
# Flying     2711   1940   1940   283     315      265      377      290    410
# Ghost     15568  14066  14066  2062    2361     2598     2539     2447   2059
# Grass     24141  29480  29480  4709    5125     4956     5425     4930   4335
# Ground    11401  14000  14000  2361    3064     2715     1807     2008   2045
# ...

# %%
df.groupby(df['Type 1']).count()
# Out:
#             #  Name  Type 2  Total  Test  Legendary   HP  Attack  Defense  \
# Type 1
# Bug        69    69      52     69    69         69   69      69       69
# Dark       31    31      21     31    31         31   31      31       31
# Dragon     32    32      21     32    32         32   32      32       32
# Electric   44    44      17     44    44         44   44      44       44
# Fairy      17    17       2     17    17         17   17      17       17
# Fighting   27    27       7     27    27         27   27      27       27
# Fire       52    52      24     52    52         52   52      52       52
# Flying      4     4       2      4     4          4    4       4        4
# Ghost      32    32      22     32    32         32   32      32       32
# Grass      70    70      37     70    70         70   70      70       70
# Ground     32    32      19     32    32         32   32      32       32
# Ice        24    24      11     24    24         24   24      24       24
# ...

# %%
df.groupby(['Type 1', 'Type 2']).count()
# Out:
#                   #  Name  Total  Test  Legendary  HP  Attack  Defense  \
# Type 1 Type 2
# Bug    Electric   2     2      2     2          2   2       2        2
#        Fighting   2     2      2     2          2   2       2        2
#        Fire       2     2      2     2          2   2       2        2
#        Flying    14    14     14    14         14  14      14       14
#        Ghost      1     1      1     1          1   1       1        1
# ...              ..   ...    ...   ...        ...  ..     ...      ...
# Water  Ice        3     3      3     3          3   3       3        3
#        Poison     3     3      3     3          3   3       3        3
#        Psychic    5     5      5     5          5   5       5        5
#        Rock       4     4      4     4          4   4       4        4
#        Steel      1     1      1     1          1   1       1        1
#
#                  Sp. Atk  Sp. Def  Speed
# Type 1 Type 2
# Bug    Electric        2        2      2
# ...

# %%
for df_new in pd.read_csv('data/mod_file.csv', chunksize=5):
    print("Chank DF")
    print(df_new)
# Out:
# Chank DF
#    Unnamed: 0  #                   Name Type 1  Type 2  Total  Test  \
# 0           0  1              Bulbasaur  Grass  Poison    318   318
# 1           1  2                Ivysaur  Grass  Poison    405   405
# 2           2  3               Venusaur  Grass  Poison    525   525
# 3           3  3  VenusaurMega Venusaur  Grass  Poison    625   625
# 4           4  4             Charmander   Fire     NaN    309   309
#
#    Legendary  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      False  45      49       49       65       65     45
# 1      False  60      62       63       80       80     60
# 2      False  80      82       83      100      100     80
# 3      False  80     100      123      122      120     80
# 4      False  39      52       43       60       50     65
# Chank DF
#    Unnamed: 0  #                       Name Type 1  Type 2  Total  Test  \
# 5           5  5                 Charmeleon   Fire     NaN    405   405
# ...
