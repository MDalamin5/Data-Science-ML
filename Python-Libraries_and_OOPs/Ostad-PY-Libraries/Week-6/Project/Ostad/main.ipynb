# %%
import pandas as pd

# %%
pay = pd.read_csv('City_of_Chicago_Payroll_Data.csv')

# %%
pay
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
pay.shape
# Out:
# (32658, 8)

# %%
pay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  object
#  7   Hourly Rate        7883 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 2.0+ MB

# %%
pay.describe()
# Out:
#        Typical Hours
# count    7883.000000
# mean       34.698719
# std         9.145553
# min        10.000000
# 25%        20.000000
# 50%        40.000000
# 75%        40.000000
# max        40.000000

# %%
pay.isnull().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        24775
# Annual Salary         7883
# Hourly Rate          24775
# dtype: int64

# %%
pay.describe(include='all')
# Out:
#                       Name      Job Titles Department Full or Part-Time  \
# count                32658           32658      32658             32658
# unique               32350            1095         36                 2
# top     HERNANDEZ,  JUAN C  POLICE OFFICER     POLICE                 F
# freq                     5            9393      12973             30676
# mean                   NaN             NaN        NaN               NaN
# std                    NaN             NaN        NaN               NaN
# min                    NaN             NaN        NaN               NaN
# 25%                    NaN             NaN        NaN               NaN
# 50%                    NaN             NaN        NaN               NaN
# 75%                    NaN             NaN        NaN               NaN
# max                    NaN             NaN        NaN               NaN
#
#        Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# ...

# %%
pay['Typical Hours'].max()
# Out:
# 40.0

# %%
pay['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    24775
# Hourly     7883
# Name: count, dtype: int64

# %%
pay.groupby('Salary or Hourly').count()[['Name']]
# Out:
#                    Name
# Salary or Hourly
# Hourly             7883
# Salary            24775

# %%
pay
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
pay['Department'].value_counts()
# Out:
# Department
# POLICE                   12973
# FIRE                      4800
# STREETS & SAN             2194
# OEMC                      2044
# WATER MGMNT               1878
# AVIATION                  1612
# TRANSPORTN                1103
# GENERAL SERVICES           972
# PUBLIC LIBRARY             932
# FAMILY & SUPPORT           621
# FINANCE                    575
# HEALTH                     516
# LAW                        405
# CITY COUNCIL               400
# BUILDINGS                  266
# COMMUNITY DEVELOPMENT      214
# BUSINESS AFFAIRS           168
# BOARD OF ELECTION          112
# DoIT                       101
# PROCUREMENT                 86
# MAYOR'S OFFICE              85
# CITY CLERK                  85
# CULTURAL AFFAIRS            76
# ANIMAL CONTRL               73
# HUMAN RESOURCES             68
# INSPECTOR GEN               63
# IPRA                        56
# BUDGET & MGMT               44
# ADMIN HEARNG                38
# ...

# %%
pay.groupby('Department').count()[['Name']].idxmax()
# Out:
# Name    POLICE
# dtype: object

# %%
pay['Department'].value_counts().head(1)
# Out:
# Department
# POLICE    12973
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="color:green">how many employee are on salary and how many are on hourly in police department</h2>

# %%
new_pay = pay[pay['Department'] == 'POLICE']
new_pay
# Out:
#                         Name      Job Titles Department Full or Part-Time  \
# 1            BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 4           DOLAN,  ROBERT J        SERGEANT     POLICE                 F
# 7            ELKINS,  ERIC J        SERGEANT     POLICE                 F
# 8           ESTRADA,  LUIS F  POLICE OFFICER     POLICE                 F
# 9            EWING,  MARIE A       CLERK III     POLICE                 F
# ...                      ...             ...        ...               ...
# 32652       ZYGMUNT,  DAWID   POLICE OFFICER     POLICE                 F
# 32653     ZYGOWICZ,  PETER J  POLICE OFFICER     POLICE                 F
# 32654  ZYLINSKA,  KATARZYNA   POLICE OFFICER     POLICE                 F
# 32655      ZYMANTAS,  MARK E  POLICE OFFICER     POLICE                 F
# 32656    ZYRKOWSKI,  CARLO E  POLICE OFFICER     POLICE                 F
#
#       Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# ...

# %%
new_pay['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    12941
# Hourly       32
# Name: count, dtype: int64

# %%
# what are the max, min, and avg typical hours (use Typical Hours column)

# %%
pay['Typical Hours'].max()
# Out:
# 40.0

# %%
# what are the max, min, and avg typical hours (use Anoual Salary column)

# %%
pay['Salary'] = pay['Annual Salary'].str.replace('$', '').astype(float)
pay
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
pay['Salary'].describe()
# Out:
# count     24775.000000
# mean      87512.780241
# std       20563.723361
# min           0.960000
# 25%       76932.000000
# 50%       90024.000000
# 75%       97368.000000
# max      300000.000000
# Name: Salary, dtype: float64

# %%
pay[pay['Salary'] == pay['Salary'].max()][['Name', 'Salary']]
# Out:
#                   Name    Salary
# 8310  EVANS,  GINGER S  300000.0
