# %% [markdown]
# # Reverse row & Column Order

# %%
import pandas as pd

# %%
drinks = pd.read_csv('data/drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.loc[1 : 5]
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol      continent
# 1                           4.9         Europe
# 2                           0.7         Africa
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
drinks.loc[1 : 6 : 3]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 1  Albania             89              132             54
# 4   Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 1                           4.9    Europe
# 4                           5.9    Africa

# %%
df = drinks.loc[::-1].reset_index(drop=True)
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0       Zimbabwe             64               18              4
# 1         Zambia             32               19              4
# 2          Yemen              6                0              0
# 3        Vietnam            111                2              1
# 4      Venezuela            333              100              3
# ..           ...            ...              ...            ...
# 188       Angola            217               57             45
# 189      Andorra            245              138            312
# 190      Algeria             25                0             14
# 191      Albania             89              132             54
# 192  Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol      continent
# 0                             4.7         Africa
# 1                             2.5         Africa
# ...

# %%
df = df.loc[:, ::-1]
df
# Out:
#          continent  total_litres_of_pure_alcohol  wine_servings  \
# 0           Africa                           4.7              4
# 1           Africa                           2.5              4
# 2             Asia                           0.1              0
# 3             Asia                           2.0              1
# 4    South America                           7.7              3
# ..             ...                           ...            ...
# 188         Africa                           5.9             45
# 189         Europe                          12.4            312
# 190         Africa                           0.7             14
# 191         Europe                           4.9             54
# 192           Asia                           0.0              0
#
#      spirit_servings  beer_servings      country
# 0                 18             64     Zimbabwe
# 1                 19             32       Zambia
# ...
