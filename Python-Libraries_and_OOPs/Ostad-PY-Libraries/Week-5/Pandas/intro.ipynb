# %%
import pandas as pd

# %%
df = pd.read_csv('data/climate_data.csv')
df
# Out:
#         day  temperature  windspeed   event
# 0  1/1/2023           27          3  Cloudy
# 1  1/2/2023           31          6   Rainy
# 2  1/3/2023           34          9   Sunny

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_excel('data/climate_data.xlsx', 'Sheet1')
df
# Out:
#          day  temperature  windspeed   event
# 0 2023-01-01           27          3  Cloudy
# 1 2023-01-02           31          6   Rainy
# 2 2023-01-03           34          9   Sunny

# %%
climet_data = {
    'day' : ['2023-01-01', '2023-01-02', '2023-01-03'],
    'temperature' : [27, 31, 34], 
    'windspeed' : [3, 6, 9],
    'event' : ['Cloudy', 'Rainy', 'Sunny']
}
df = pd.DataFrame(climet_data)
df
# Out:
#           day  temperature  windspeed   event
# 0  2023-01-01           27          3  Cloudy
# 1  2023-01-02           31          6   Rainy
# 2  2023-01-03           34          9   Sunny

# %%
climet_data = [
    ('2023-01-01', 27, 3, 'Cloudy'),
    ('2023-01-02', 31, 6, 'Rainy'),
    ('2023-01-03', 34, 9, 'Sunny'),
]

df = pd.DataFrame(data = climet_data, columns=['day', 'temperature', 'windspeed', 'event'])
df
# Out:
#           day  temperature  windspeed   event
# 0  2023-01-01           27          3  Cloudy
# 1  2023-01-02           31          6   Rainy
# 2  2023-01-03           34          9   Sunny

# %%
# Out:
#           day  temp  Windspeed  events
# 0  2023-01-01   NaN        NaN     NaN
# 1  2023-01-02   NaN        NaN     NaN
# 2  2023-01-03   NaN        NaN     NaN

# %%
# Using List Of Dictionary
climet_data = [
    {'day' : '2023-01-01', 'temperature' : 27, 'windspeed' : 3, 'event' : 'Cloudy'},
    {'day' : '2023-01-02', 'temperature' : 27, 'windspeed' : 3, 'event' : 'Cloudy'},
    {'day' : '2023-01-03', 'temperature' : 27, 'windspeed' : 3, 'event' : 'Cloudy'}
    ]
df = pd.DataFrame(data= climet_data, columns=['day', 'temperature', 'windspeed', 'event'])
df
# Out:
#           day  temperature  windspeed   event
# 0  2023-01-01           27          3  Cloudy
# 1  2023-01-02           27          3  Cloudy
# 2  2023-01-03           27          3  Cloudy

# %%
df = pd.read_clipboard()
df
# Out:
#          Name   Rent  Service Charge  Wifi  Current     Bua  Extra Cost  \
# 0  Md Al Amin   7000             750   500    250.0   625.0          25
# 1      Kaysar   2250             750   500    250.0   625.0          25
# 2      Shahin   2250             750   500    250.0   625.0          25
# 3      Shihab   4750             750   300    250.0   625.0          25
# 4       Omlan   4750             750   300    250.0   625.0          25
# 5        Eram   3000             750   300    250.0   625.0          25
# 6      Musfiq   3000             750   300    250.0   625.0          25
# 7      Kamrul   3000             750   300    250.0   625.0          25
# 8     Extra-1      0               0     0      NaN     NaN           0
# 9       Total  30000            6000  3000   2000.0  5000.0         200
#
#    Per Person  Have To Pay  Take From
# 0        9150          NaN     9200.0
# 1        4400          NaN     4500.0
# 2        4400          NaN     4500.0
# 3        6700          NaN     6700.0
# 4        6700          NaN     6720.0
# 5        4950          NaN     5000.0
# 6        4950          NaN     5000.0
# 7        4950          NaN     5000.0
# 8           0          NaN        NaN
# 9       46200          0.0    46620.0
